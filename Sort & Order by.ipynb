# %% [markdown]
# # Sort & Order by

# %%
df = spark.read.format('csv').option("header", "true").load('/Volumes/development/data/files/orders/orders.csv')
display(df.sort(df.customer_name.asc()))

# %%
display(df.orderBy(df.customer_name.asc(), df.order_date.asc()))

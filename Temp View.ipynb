# %% [markdown]
# # Temp View

# %%
df = spark.read.format('parquet').load('/Volumes/development/data/files/orders/orders.parquet')

# %%
df.createOrReplaceTempView('orders')

# %%
# %sql
select * from  orders
where product = 'Laptop'
limit 5

# %% [markdown]
# ## this is not included with the topic it's just me missing around

# %%
df_laptop = spark.sql("""
                      select * from orders
                      where product = 'Laptop'
                      limit 5
                      """)
display(df_laptop)

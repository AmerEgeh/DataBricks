# %% [markdown]
# # Handle null values

# %%
df = spark.read.format('parquet').load('/Volumes/development/data/files/orders/orders.parquet')
display(df)

# %%
display(df.fillna(''))

# %%
display(df.fillna('',['quantity']).fillna(0,['order_id']))

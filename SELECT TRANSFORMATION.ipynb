# %% [markdown]
# # SELECT TRANSFORMATION

# %%
df = spark.read.format('csv').option('header','true').option('inferschema','true').load('/Volumes/development/data/files/orders/orders.csv')
df.select(df.order_id, df.customer_name).show()

# %%
display(df.select("order_id", "customer_name"))

# %% [markdown]
# # RENAME A COLUMN

# %%
from pyspark.sql.functions import *
display(df.select("order_id", "customer_name", col('customer_name').alias('customer')))

# %%
display(df)
